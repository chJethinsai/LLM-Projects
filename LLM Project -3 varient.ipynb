# %%
import re
import os
import io
import sys
import subprocess
from dotenv import load_dotenv
from openai import OpenAI
import google.generativeai as genai
import anthropic
import execjs
import gradio as gr

# Load environment variables
load_dotenv()
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY', 'your-key-if-not-using-env')
os.environ['ANTHROPIC_API_KEY'] = os.getenv('ANTHROPIC_API_KEY', 'your-key-if-not-using-env')
os.environ['GOOGLE_API_KEY'] = os.getenv('GOOGLE_API_KEY','your-key-if-not-using-env')
# Initialize API Clients
openai = OpenAI()
claude = anthropic.Anthropic()
google.generativeai.configure()
# Default AI Models
OPENAI_MODEL = "gpt-4o"
CLAUDE_MODEL = "claude-3-5-sonnet-20240620"
GEMINI_MODEL ='gemini-1.5-flash'

# %%
def optimize(input_code, output_code, model):
    """Optimizes input code and converts it to the desired output language using AI."""
    user_prompt = (
        f"Rewrite this {input_code} code in C++ with the fastest possible implementation that produces identical output in the least time. "
        f"Respond only with {output_code} code; do not explain your work other than a few comments. "
        f"Pay attention to number types to ensure no int overflows. Remember to #include all necessary {output_code} packages such as iomanip.\n\n"
        f"{input_code}"
    )
    
    system_message = (
        f"You are an assistant that reimplements {input_code} code in high-performance {output_code}. "
        f"Respond only with {output_code} code; use comments sparingly and do not provide any explanation other than occasional comments. "
        f"The {output_code} response needs to produce an identical output in the fastest possible time."
    )

    if model == "GPT":
        return get_gpt_response(system_message, user_prompt)
    elif model == "Claude":
        return get_claude_response(system_message, user_prompt)
    elif model == "Gemini":
        return get_gemini_response(system_message, user_prompt)
    else:
        raise ValueError("Unknown model")

# %%
def write_output(code):
    """Removes markdown syntax from C++ and JavaScript code blocks."""
    return re.sub(r"```(cpp|javascript)?", "", code).strip()

def get_gpt_response(system_message, user_prompt): 
    """Gets output from OpenAI GPT model without streaming."""
    response = openai.chat.completions.create(
        model=OPENAI_MODEL, 
        messages=[{"role": "system", "content": system_message}, {"role": "user", "content": user_prompt}]
    )
    reply = response.choices[0].message.content
    return write_output(reply)

def get_gemini_response(system_message, user_prompt):
    """Gets output from Google Gemini model without streaming."""
    gemini = genai.GenerativeModel(
        model_name=GEMINI_MODEL,
        system_instruction=system_message
    )
    response = gemini.generate_content(user_prompt)
    reply = response.text
    return write_output(reply)

def get_claude_response(system_message, user_prompt):
    """Gets a complete response from Claude AI model without streaming."""
    response = claude.messages.create(
        model=CLAUDE_MODEL,
        max_tokens=2000,
        system=system_message,
        messages=[{"role": "user", "content": user_prompt}]
    )
    return response.content[0].text

# %%
def runthecode(language, code):
    """Runs the given code based on the specified language."""
    if language == 'C++':
        return execute_cpp(code)
    elif language == 'Python':
        return execute_python(code)
    elif language == 'JavaScript':
        return execute_javascript(code)
    else:
        return "Unsupported language"

def execute_cpp(code):
    """Compiles and runs C++ code."""
    try:
        with open("optimized.cpp", "w") as file:
            file.write(code)

        compile_cmd = ["clang++", "-Ofast", "-std=c++17", "-march=armv8.5-a", "-mtune=apple-m1", "-mcpu=apple-m1", "-o", "optimized", "optimized.cpp"]
        subprocess.run(compile_cmd, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

        run_cmd = ["./optimized"]
        run_result = subprocess.run(run_cmd, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
        
        return run_result.stdout
    except subprocess.CalledProcessError as e:
        return f"An error occurred:\n{e.stderr}"

def execute_python(code):
    try:
        output = io.StringIO()
        sys.stdout = output
        exec(code)
    finally:
        sys.stdout = sys.__stdout__
    return output.getvalue()

def execute_javascript(js_code):
    """Executes JavaScript code using Node.js."""
    try:
        output = execjs.eval(js_code)
        return str(output)
    except Exception as e:
        return f"Error: {str(e)}"

# %%
# CSS for UI
css = """
.code_language {background-color: #FFFFE0;}
.inputcode {background-color: #ADD8E6;}
.outputcode {background-color: #E6E6FA;}
.compiler{background-color: #FF7F7F;}
"""

# Gradio UI
with gr.Blocks(css=css) as ui:
    gr.Markdown("## Convert code from Python to C++")
    gr.Markdown("### You cannot have both input and output codes as the same")

    with gr.Row():
        input_code = gr.Dropdown(['JavaScript', 'Python', 'C++'], label="Given Language Code", value="Python", elem_classes=["code_language"])
        output_code = gr.Dropdown(['JavaScript', 'Python', 'C++'], label="Convert To", value="C++",elem_classes=["code_language"])

    with gr.Row():
        inputs = gr.Textbox(label="Input Code:", lines=10,interactive=True,elem_classes=["inputcode"])
        outputs = gr.Textbox(label="Converted Code:", lines=10,interactive=True,elem_classes=["inputcode"])

    with gr.Row():
        model = gr.Dropdown(["GPT", "Claude","Gemini"], label="Select Model", value="GPT",elem_classes=["outputcode"])

    with gr.Row():
        convert = gr.Button("Convert Code")

    with gr.Row():
        input_run = gr.Button("Run Input Code")
        output_run = gr.Button("Run Output Code")

    with gr.Row():
        inputs_compiler = gr.TextArea(label="Input Result:", elem_classes=["compiler"])
        outputs_compiler = gr.TextArea(label="Output Result:", elem_classes=["compiler"])

    # Button event handlers
    convert.click(optimize, inputs=[inputs, output_code, model], outputs=[outputs])
    input_run.click(runthecode, inputs=[input_code, inputs], outputs=[inputs_compiler])
    output_run.click(runthecode, inputs=[output_code, outputs], outputs=[outputs_compiler])

ui.launch(inbrowser=True)
# Out:
# <div><iframe src="http://127.0.0.1:7871/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/gradio/queueing.py", line 625, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/gradio/route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/gradio/blocks.py", line 2044, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/gradio/blocks.py", line 1591, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 2461, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 962, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/gradio/utils.py", line 883, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/var/folders/rk/z66pz7fn6dsc_dq5gmc76dmr0000gn/T/ipykernel_6120/3297869695.py", line 19, in optimize
#     return get_claude_response(system_message, user_prompt)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/rk/z66pz7fn6dsc_dq5gmc76dmr0000gn/T/ipykernel_6120/3314429941.py", line 26, in get_claude_response
#     response = claude.messages.create(
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/anthropic/_utils/_utils.py", line 275, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/anthropic/resources/messages/messages.py", line 904, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/anthropic/_base_client.py", line 1282, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/anthropic/_base_client.py", line 959, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/anthropic/_base_client.py", line 1048, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/anthropic/_base_client.py", line 1097, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/anthropic/_base_client.py", line 1048, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/anthropic/_base_client.py", line 1097, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/anthropic/_base_client.py", line 1063, in _request
#     raise self._make_status_error_from_response(err.response) from None
# anthropic.InternalServerError: Error code: 529 - {'type': 'error', 'error': {'type': 'overloaded_error', 'message': 'Overloaded'}}
